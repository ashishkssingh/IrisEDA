# %%
import numpy as np    #Load the numpy library for fast array computations
import pandas as pd   #Load the pandas data-analysis library
import matplotlib.pyplot as plt   #Load the pyplot visualization library
import seaborn as sns

sns.set_style("darkgrid")
# %matplotlib inline

# %%
from sklearn import datasets
dataset = datasets.load_iris()

# %%
data=pd.DataFrame(dataset['data'],columns=["Petal length","Petal Width","Sepal Length","Sepal Width"])

# %%
data['Species']=dataset['target']
data['Species_target']=data['Species'].apply(lambda x: dataset['target_names'][x])

# %%
data.head()
# Out:
#    Petal length  Petal Width  Sepal Length  Sepal Width  Species  \
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0
#
#   Species_target
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa

# %%
data.shape
# Out:
# (150, 6)

# %%
data.describe()
# Out:
#        Petal length  Petal Width  Sepal Length  Sepal Width     Species
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.057333      3.758000     1.199333    1.000000
# std        0.828066     0.435866      1.765298     0.762238    0.819232
# min        4.300000     2.000000      1.000000     0.100000    0.000000
# 25%        5.100000     2.800000      1.600000     0.300000    0.000000
# 50%        5.800000     3.000000      4.350000     1.300000    1.000000
# 75%        6.400000     3.300000      5.100000     1.800000    2.000000
# max        7.900000     4.400000      6.900000     2.500000    2.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Petal length      150 non-null float64
# Petal Width       150 non-null float64
# Sepal Length      150 non-null float64
# Sepal Width       150 non-null float64
# Species           150 non-null int64
# Species_target    150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.isnull().sum()
# Out:
# Petal length      0
# Petal Width       0
# Sepal Length      0
# Sepal Width       0
# Species           0
# Species_target    0
# dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.pairplot(data=data,diag_kind="hist",hue="Species_target")

# %%
sns.heatmap(data.corr(),annot=True)

# %% [markdown]
# **Species is least dependent on Petal width.

# %%
sns.scatterplot(x="Petal length", y="Petal Width",hue="Species_target", data=data)

# %%
plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
sns.scatterplot(x="Petal length", y="Petal Width",hue="Species_target", data=data)

plt.subplot(2,2,2)
sns.scatterplot(x="Petal length", y="Sepal Width",hue="Species_target", data=data)

plt.subplot(2,2,3)
sns.scatterplot(x="Sepal Length", y="Petal Width",hue="Species_target", data=data)

plt.subplot(2,2,4)
sns.scatterplot(x="Sepal Length", y="Sepal Width",hue="Species_target", data=data)

# %% [markdown]
# ### ** Understanding from Scatter plots:**
#  - Species is least dependent on petal width.

# %%
plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
sns.violinplot(x="Species_target", y="Petal length", data=data)

plt.subplot(2,2,2)
sns.violinplot(x="Species_target", y="Petal Width", data=data)

plt.subplot(2,2,3)
sns.violinplot(x="Species_target", y="Sepal Length", data=data)

plt.subplot(2,2,4)
sns.violinplot(x="Species_target", y="Sepal Width", data=data)

# %% [markdown]
# ### **Understanding from violinplots:**
#  - There is no overlapping in case of Sepal length and Sepal Width which confirms it's importance in classifying species
